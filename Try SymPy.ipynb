# %%
from sympy import init_session
init_session()
# Out:
# IPython console for SymPy 1.5.1 (Python 3.6.9-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.5.1/

# %%
my_integral = Integral(cos(x*x)*exp(x**2), x)

# %%
my_integral
# Out:
# ⌠
# ⎮  ⎛ 2⎞
# ⎮  ⎝x ⎠    ⎛ 2⎞
# ⎮ ℯ    ⋅cos⎝x ⎠ dx
# ⌡

# %%
Eq(my_integral, y)
# Out:
# ⌠
# ⎮  ⎛ 2⎞
# ⎮  ⎝x ⎠    ⎛ 2⎞
# ⎮ ℯ    ⋅cos⎝x ⎠ dx = y
# ⌡

# %%
my_integral.doit()
# Out:
#                 ⎛                                          │     -4⋅ⅈ⋅π⎞
# 4 ___   ╭─╮0, 6 ⎜-1/8, 1/8, 3/8, 5/8, 7/8, 1      3/8      │ 64⋅ℯ      ⎟
# ╲╱ 2 ⋅ⅈ⋅│╶┐     ⎜                                          │ ──────────⎟
#         ╰─╯7, 3 ⎜                             -1/8, 3/8, 0 │      8    ⎟
#                 ⎝                                          │     x     ⎠
# ────────────────────────────────────────────────────────────────────────
#                                   8⋅√π

# %%
p = poly(x**3 + 7*x**2 + x + 17)
p
# Out:
# Poly(x**3 + 7*x**2 + x + 17, x, domain='ZZ')

# %%
for rt in roots(p, x):
    display(rt)
# Out:
#   3 ________________
#   ╲╱ 3⋅√21705 + 541    7            46
# - ────────────────── - ─ - ────────────────────
#           3            3     3 ________________
#                            3⋅╲╱ 3⋅√21705 + 541
#       ⎛  1   √3⋅ⅈ⎞ 3 ________________
#       ⎜- ─ + ────⎟⋅╲╱ 3⋅√21705 + 541
#   7   ⎝  2    2  ⎠                                      46
# - ─ - ─────────────────────────────── - ─────────────────────────────────
#   3                  3                    ⎛  1   √3⋅ⅈ⎞ 3 ________________
#                                         3⋅⎜- ─ + ────⎟⋅╲╱ 3⋅√21705 + 541
#                                           ⎝  2    2  ⎠
#                                           ⎛  1   √3⋅ⅈ⎞ 3 ________________
#                                           ⎜- ─ - ────⎟⋅╲╱ 3⋅√21705 + 541
#   7                   46                  ⎝  2    2  ⎠
# - ─ - ───────────────────────────────── - ───────────────────────────────
#   3     ⎛  1   √3⋅ⅈ⎞ 3 ________________                  3
# ...

# %%
r = symbols('r')

# %%
p = poly(3100*(1+r)**3 + 3100*(1+r)**2 + 4500*(1+r) + 100 - 14977.28)

for rt in roots(p, r):
    display(rt)
# Out:
# 0.186334474371810
# -2.0931672371859 - 1.68828974237954⋅ⅈ
# -2.0931672371859 + 1.68828974237954⋅ⅈ

# %%
p = poly(4100*(1+r)**3 + 23292.76*(1+r)**2 + 34108.2*(1+r) + 100 - 70886.12, domain='RR')

for rt in roots(p, r):
    display(rt)
# Out:
# 0.0962612551986578
# -4.38871111540421 - 2.06531729979318⋅ⅈ
# -4.38871111540421 + 2.06531729979318⋅ⅈ
